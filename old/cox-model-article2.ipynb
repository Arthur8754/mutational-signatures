# %% [markdown]
# # Cox model execution - 2nd article
#
# In this notebook, we test the cox model for the following article : https://www.nature.com/articles/s41591-023-02324-5

# %%
import pandas as pd

# %% [markdown]
# ## Reading and preprocessing
# We want to read the ```supp-tables.xlsx``` file, and the 2.1 sheet of this file.
#
# The columns which are useful in this article are :
# - `Age_at_dx`
# - `AJCC_path_stage`
# - MSI status
# - CMS
# - ICR score
# - ICR cluster
# - GIE
# - MBR group
# - `OS_Time`
# - `OS_Status`
# - `PFS_Time`
# - `PFS_Status`

# %%
df = pd.read_excel('data/supp-tables.xlsx',sheet_name='2.1_Clinical_Data_AC_ICAM',header=1)
df
# Out:
#             Patient_ID Self-reported sex Tumor_anatomic_location
# 0    SER-SILU-CC-P0002            FEMALE        colon sigmoideum  \
# 1    SER-SILU-CC-P0004              MALE        flexura hepatica
# 2    SER-SILU-CC-P0005              MALE        colon descendens
# 3    SER-SILU-CC-P0007            FEMALE        colon descendens
# 4    SER-SILU-CC-P0009            FEMALE         colon ascendens
# ..                 ...               ...                     ...
# 343  SER-SILU-CC-P0444              MALE        colon sigmoideum
# 344  SER-SILU-CC-P0446            FEMALE         rectosigmoideum
# 345  SER-SILU-CC-P0450              MALE         rectosigmoideum
# 346  SER-SILU-CC-P0451            FEMALE        colon sigmoideum
# 347  SER-SILU-CC-P0452              MALE         rectosigmoideum
#
#                    Tumor_morphology History_of_cancer Neoadjuvant_treated
# 0                    adenocarcinoma                No                  No  \
# ...
